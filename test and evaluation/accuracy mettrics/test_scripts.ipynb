# %%
# %%capture
# !pip install ultralytics
# !pip install onnx
# !pip install onnx_tf
# !pip install matplotlib
# !pip install protobuf==3.20.1
# !pip install keras==2.11.0
# !pip install tensorflow-estimator==2.11.0
# !pip install tensorboard==2.11.0
# !pip install torchinfo
# !pip install torchview

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %% [markdown]
# #Early Exit based model - Backbone + Neck

# %%
#Normal Trained model(without Pruning and Quantization) - pt
# !python /content/drive/MyDrive/EE_using_ultralitycs/test_scripts/test_and_validation.py \
  --model /content/drive/MyDrive/EE_using_ultralitycs/results/EE_Backbone_Neck/runs/detect/yolov8n-ee/weights/best.pt \
  --test_dir /content/drive/MyDrive/dataset/dataset/test/ \
  --data_yaml /content/drive/MyDrive/dataset/dataset/data.yaml \
  --conf 0.25 \
  --iou 0.25 \
  --batch 1 \
  --project results_EE_BackboneNeck.txt
# Out:
# Ultralytics 8.3.220 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv8n_ee summary (fused): 100 layers, 5,026,702 parameters, 0 gradients, 16.5 GFLOPs
# val: Fast image access ✅ (ping: 0.7±0.7 ms, read: 23.6±13.0 MB/s, size: 60.0 KB)
# val: Scanning /content/drive/MyDrive/dataset/dataset/test/labels.cache... 1152 images, 5 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1152/1152 9.8Mit/s 0.0s
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 404, len(boxes) = 1720. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1152/1152 39.3it/s 29.3s
#                    all       1152       1720      0.885      0.824      0.884      0.725
# Speed: 1.2ms preprocess, 15.0ms inference, 0.0ms loss, 1.2ms postprocess per image
# ...

# %%
#Normal Trained model(without Pruning and Quantization) - tflite
# !python /content/drive/MyDrive/EE_using_ultralitycs/test_scripts/test_and_validation.py \
  --model /content/drive/MyDrive/EE_using_ultralitycs/results/EE_Backbone_Neck/runs/detect/yolov8n-ee/weights/best_saved_model/best_float32.tflite \
  --test_dir /content/drive/MyDrive/dataset/dataset/test/ \
  --data_yaml /content/drive/MyDrive/dataset/dataset/data.yaml \
  --conf 0.25 \
  --iou 0.25 \
  --batch 1 \
  --project results_EE_BackboneNeck_tflite.txt
# Out:
# ERROR: Model not found: /content/drive/MyDrive/EE_using_ultralitycs/results/EE_Backbone_Neck/runs/detect/yolov8n-ee/weights/best_saved_model/best_float32.tflite

# %% [markdown]
# ##Pruned model(without quantizaiton)

# %%
#Prunned model(without Quantization)
# !python /content/drive/MyDrive/EE_using_ultralitycs/test_scripts/test_and_validation.py \
  --model /content/drive/MyDrive/EE_using_ultralitycs/results/EE_Backbone_Neck/pruned/EE_backbone_neck_pruned_float32.tflite \
  --test_dir /content/drive/MyDrive/dataset/dataset/test/ \
  --data_yaml /content/drive/MyDrive/dataset/dataset/data.yaml \
  --conf 0.25 \
  --iou 0.25 \
  --batch 1 \
  --project results_EE_BackboneNeck_pruned.txt
# Out:
# WARNING ⚠️ Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify','pose' or 'obb'.
# Ultralytics 8.3.220 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1761144547.089788   22783 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1761144547.100316   22783 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1761144547.124325   22783 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %% [markdown]
# ##Quantized model(without Prunning)

# %%
#Quantized model(without Pruning) float 16
# !python /content/drive/MyDrive/EE_using_ultralitycs/test_scripts/test_and_validation.py \
  --model /content/drive/MyDrive/EE_using_ultralitycs/results/EE_Backbone_Neck/quantized/EE_Backbone_Neck_float16.tflite \
  --test_dir /content/drive/MyDrive/dataset/dataset/test/ \
  --data_yaml /content/drive/MyDrive/dataset/dataset/data.yaml \
  --conf 0.25 \
  --iou 0.25 \
  --batch 1 \
  --project results_EE_BackboneNeck_float16.txt
# Out:
# WARNING ⚠️ Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify','pose' or 'obb'.
# Ultralytics 8.3.220 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1761144918.090190   24334 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1761144918.100490   24334 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1761144918.124823   24334 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
#Quantized model(without Pruning) Int 8
# !python /content/drive/MyDrive/EE_using_ultralitycs/test_scripts/test_and_validation.py \
  --model /content/drive/MyDrive/EE_using_ultralitycs/results/EE_Backbone_Neck/quantized/EE_Backbone_Neck_int8.tflite \
  --test_dir /content/drive/MyDrive/dataset/dataset/test/ \
  --data_yaml /content/drive/MyDrive/dataset/dataset/data.yaml \
  --conf 0.25 \
  --iou 0.25 \
  --batch 1 \
  --project results_EE_BackboneNeck_int8.txt
# Out:
# WARNING ⚠️ Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify','pose' or 'obb'.
# Ultralytics 8.3.220 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1761145586.425849   27209 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1761145586.432358   27209 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1761145586.449351   27209 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %% [markdown]
# ##Quantized and Pruned model

# %%
#Quantized and Prunned model - Float 16
# !python /content/drive/MyDrive/EE_using_ultralitycs/test_scripts/test_and_validation.py \
  --model /content/drive/MyDrive/EE_using_ultralitycs/results/EE_Backbone_Neck/pruned/EE_backbone_neck_pruned_float16.tflite \
  --test_dir /content/drive/MyDrive/dataset/dataset/test/ \
  --data_yaml /content/drive/MyDrive/dataset/dataset/data.yaml \
  --conf 0.25 \
  --iou 0.25 \
  --batch 1 \
  --project results_EE_BackboneNeck_pruned_float16.txt
# Out:
# WARNING ⚠️ Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify','pose' or 'obb'.
# Ultralytics 8.3.220 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1761140929.697850    7184 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1761140929.704367    7184 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1761140929.721252    7184 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
#Quantized and Prunned model - Int 8
# !python /content/drive/MyDrive/EE_using_ultralitycs/test_scripts/test_and_validation.py \
  --model /content/drive/MyDrive/EE_using_ultralitycs/results/EE_Backbone_Neck/pruned/EE_backbone_neck_pruned_int8.tflite \
  --test_dir /content/drive/MyDrive/dataset/dataset/test/ \
  --data_yaml /content/drive/MyDrive/dataset/dataset/data.yaml \
  --conf 0.25 \
  --iou 0.25 \
  --batch 1 \
  --project results_EE_BackboneNeck_pruned_int8.txt
# Out:
# WARNING ⚠️ Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify','pose' or 'obb'.
# Ultralytics 8.3.220 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1761141599.895144   10078 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1761141599.901400   10078 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1761141599.917632   10078 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %% [markdown]
# #Early Eixt Based model - Backboneonly

# %%
#Normal Trained model(without Pruning and Quantization) - pt
# !python /content/drive/MyDrive/EE_using_ultralitycs/test_scripts/test_and_validation.py \
  --model /content/drive/MyDrive/EE_using_ultralitycs/results/EE_Backboneonly/yolov8n-ee/weights/best.pt \
  --test_dir /content/drive/MyDrive/dataset/dataset/test/ \
  --data_yaml /content/drive/MyDrive/dataset/dataset/data.yaml \
  --conf 0.25 \
  --iou 0.25 \
  --batch 1 \
  --project results_EE_Backboneonly.txt
# Out:
# Ultralytics 8.3.209 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv8n_ee summary (fused): 100 layers, 5,026,702 parameters, 0 gradients, 16.5 GFLOPs
# val: Fast image access ✅ (ping: 0.6±0.2 ms, read: 24.3±14.8 MB/s, size: 42.0 KB)
# val: Scanning /content/drive/MyDrive/dataset/dataset/test/labels.cache... 1152 images, 5 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1152/1152 15.0Mit/s 0.0s
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 404, len(boxes) = 1720. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1152/1152 47.6it/s 24.2s
#                    all       1152       1720      0.885      0.824      0.884      0.725
# ...

# %% [markdown]
# ##Pruned model(without quantizaiton)

# %%
#Prunned model(without Quantization)
# !python /content/drive/MyDrive/EE_using_ultralitycs/test_scripts/test_and_validation.py \
  --model /content/drive/MyDrive/EE_using_ultralitycs/results/EE_Backboneonly/pruned/EE_backboneonly_manual_pruned_float32.tflite \
  --test_dir /content/drive/MyDrive/dataset/dataset/test/ \
  --data_yaml /content/drive/MyDrive/dataset/dataset/data.yaml \
  --conf 0.25 \
  --iou 0.25 \
  --batch 1 \
  --project results_EE_Backboneonly_pruned.txt
# Out:
# WARNING ⚠️ Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify','pose' or 'obb'.
# Ultralytics 8.3.217 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1760970615.415245   22728 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1760970615.430244   22728 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1760970615.462969   22728 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %% [markdown]
# ##Quantized model(without Prunning)

# %%
#Quantized model(without Pruning) float 16
# !python /content/drive/MyDrive/EE_using_ultralitycs/test_scripts/test_and_validation.py \
  --model /content/drive/MyDrive/EE_using_ultralitycs/results/EE_Backboneonly/quantized/EE_Backbone_only_float16.tflite \
  --test_dir /content/drive/MyDrive/dataset/dataset/test/ \
  --data_yaml /content/drive/MyDrive/dataset/dataset/data.yaml \
  --conf 0.25 \
  --iou 0.25 \
  --batch 1 \
  --project results_EE_Backboneonly_float16.txt
# Out:
# WARNING ⚠️ Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify','pose' or 'obb'.
# Ultralytics 8.3.209 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1760139495.264526    9939 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1760139495.274630    9939 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1760139495.300706    9939 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
#Quantized model(without Pruning) Int 8
# !python /content/drive/MyDrive/EE_using_ultralitycs/test_scripts/test_and_validation.py \
  --model /content/drive/MyDrive/EE_using_ultralitycs/results/EE_Backboneonly/quantized/EE_Backbone_only_int8.tflite \
  --test_dir /content/drive/MyDrive/dataset/dataset/test/ \
  --data_yaml /content/drive/MyDrive/dataset/dataset/data.yaml \
  --conf 0.25 \
  --iou 0.25 \
  --batch 1 \
  --project results_EE_BackboneNeck_int8.txt
# Out:
# WARNING ⚠️ Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify','pose' or 'obb'.
# Ultralytics 8.3.209 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1760140074.629378   12444 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1760140074.639065   12444 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1760140074.662534   12444 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %% [markdown]
# ##Quantized and Pruned model

# %%
#Quantized and Prunned model - Float 16
# !python /content/drive/MyDrive/EE_using_ultralitycs/test_scripts/test_and_validation.py \
  --model /content/drive/MyDrive/EE_using_ultralitycs/results/EE_Backboneonly/pruned/EE_backboneonly_manual_pruned_float16.tflite\
  --test_dir /content/drive/MyDrive/dataset/dataset/test/ \
  --data_yaml /content/drive/MyDrive/dataset/dataset/data.yaml \
  --conf 0.25 \
  --iou 0.25 \
  --batch 1 \
  --project results_EE_Backboneonly_pruned_float16.txt

# %%
#Quantized and Prunned model - Int 8
# !python /content/drive/MyDrive/EE_using_ultralitycs/test_scripts/test_and_validation.py \
  --model /content/drive/MyDrive/EE_using_ultralitycs/results/EE_Backboneonly/quantized/EE_backboneonly_manual_pruned_int8.tflite \
  --test_dir /content/drive/MyDrive/dataset/dataset/test/ \
  --data_yaml /content/drive/MyDrive/dataset/dataset/data.yaml \
  --conf 0.25 \
  --iou 0.25 \
  --batch 1 \
  --project results_EE_Backboneonly_pruned_int8.txt

# %% [markdown]
# #Trained Model Without Early Exit layers

# %%
#Normal Trained model(without Pruning and Quantization) - pt
# !python /content/drive/MyDrive/EE_using_ultralitycs/test_scripts/test_and_validation.py \
  --model /content/drive/MyDrive/EE_using_ultralitycs/results/Model_without_EE/train-results/weights/best.pt \
  --test_dir /content/drive/MyDrive/dataset/dataset/test/ \
  --data_yaml /content/drive/MyDrive/dataset/dataset/data.yaml \
  --conf 0.25 \
  --iou 0.25 \
  --batch 1 \
  --project results_simple_customised_yolov8.txt
# Out:
# Ultralytics 8.3.220 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv8n summary (fused): 72 layers, 3,009,158 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 0.7±0.2 ms, read: 26.5±10.2 MB/s, size: 55.2 KB)
# val: Scanning /content/drive/MyDrive/dataset/dataset/test/labels.cache... 1152 images, 5 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1152/1152 12.8Mit/s 0.0s
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 404, len(boxes) = 1720. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1152/1152 44.7it/s 25.8s
#                    all       1152       1720      0.855      0.843      0.882      0.727
# Speed: 1.2ms preprocess, 11.3ms inference, 0.0ms loss, 1.5ms postprocess per image
# ...

# %% [markdown]
# ##Pruned model(without quantizaiton)

# %%
#Pruned model(withoutearly exit and Quantization)
# !python /content/drive/MyDrive/EE_using_ultralitycs/test_scripts/test_and_validation.py \
  --model /content/drive/MyDrive/EE_using_ultralitycs/results/Model_without_EE/pruned/customized_without_EE_pruned_float32.tflite \
  --test_dir /content/drive/MyDrive/dataset/dataset/test/ \
  --data_yaml /content/drive/MyDrive/dataset/dataset/data.yaml \
  --conf 0.25 \
  --iou 0.25 \
  --batch 1 \
  --project results_customized_without_EE_pruned.txt
# Out:
# WARNING ⚠️ Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify','pose' or 'obb'.
# Ultralytics 8.3.220 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1761142335.454170   13247 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1761142335.460678   13247 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1761142335.476038   13247 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %% [markdown]
# ##Quantized Model(without Pruning)

# %%
#Quantized model(without Pruning) - Float16
# !python /content/drive/MyDrive/EE_using_ultralitycs/test_scripts/test_and_validation.py \
  --model /content/drive/MyDrive/EE_using_ultralitycs/results/Model_without_EE/quantized/best_yolov8_float16.tflite \
  --test_dir /content/drive/MyDrive/dataset/dataset/test/ \
  --data_yaml /content/drive/MyDrive/dataset/dataset/data.yaml \
  --conf 0.25 \
  --iou 0.25 \
  --batch 1 \
  --project results_simple_customised_yolov8_float16.txt
# Out:
# WARNING ⚠️ Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify','pose' or 'obb'.
# Ultralytics 8.3.220 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1761147724.154015   36417 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1761147724.160176   36417 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1761147724.175958   36417 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
#Quantized model(without Pruning) - Int8
# !python /content/drive/MyDrive/EE_using_ultralitycs/test_scripts/test_and_validation.py \
  --model /content/drive/MyDrive/EE_using_ultralitycs/results/Model_without_EE/quantized/best_yolov8_int8.tflite \
  --test_dir /content/drive/MyDrive/dataset/dataset/test/ \
  --data_yaml /content/drive/MyDrive/dataset/dataset/data.yaml \
  --conf 0.25 \
  --iou 0.25 \
  --batch 1\
  --project results_simple_customised_yolov8_int8.txt
# Out:
# WARNING ⚠️ Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify','pose' or 'obb'.
# Ultralytics 8.3.220 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1761148166.255496   38321 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1761148166.261720   38321 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1761148166.277377   38321 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %% [markdown]
# ##Quantized and Pruned Model

# %%
#Quantized and Pruned model - Float16
# !python /content/drive/MyDrive/EE_using_ultralitycs/test_scripts/test_and_validation.py \
  --model /content/drive/MyDrive/EE_using_ultralitycs/results/Model_without_EE/pruned/customized_without_EE_pruned_float16.tflite \
  --test_dir /content/drive/MyDrive/dataset/dataset/test/ \
  --data_yaml /content/drive/MyDrive/dataset/dataset/data.yaml \
  --conf 0.25 \
  --iou 0.25 \
  --batch 1 \
  --project results_simple_customised_yolov8_pruned_float16.txt
# Out:
# WARNING ⚠️ Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify','pose' or 'obb'.
# Ultralytics 8.3.220 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1761142730.098038   14956 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1761142730.107790   14956 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1761142730.131625   14956 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
#Quantized and Pruned model - Int8
# !python /content/drive/MyDrive/EE_using_ultralitycs/test_scripts/test_and_validation.py \
  --model /content/drive/MyDrive/EE_using_ultralitycs/results/Model_without_EE/pruned/customized_without_EE_pruned_int8.tflite \
  --test_dir /content/drive/MyDrive/dataset/dataset/test/ \
  --data_yaml /content/drive/MyDrive/dataset/dataset/data.yaml \
  --conf 0.25 \
  --iou 0.25 \
  --batch 1 \
  --project results_simple_customised_yolov8_pruned_int8.txt
# Out:
# WARNING ⚠️ Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify','pose' or 'obb'.
# Ultralytics 8.3.220 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1761143128.769612   16677 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1761143128.775707   16677 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1761143128.790809   16677 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...
