# %%
# %%capture
# !pip install ultralytics
# !pip install onnx
# !pip install onnx_tf
# !pip install matplotlib
# !pip install protobuf==3.20.1
# !pip install keras==2.11.0
# !pip install tensorflow-estimator==2.11.0
# !pip install tensorboard==2.11.0
# !pip install torchinfo
# !pip install torchview

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %% [markdown]
# #Early Exit based model - Backbone + Neck

# %%
#Normal Trained model(without Pruning and Quantization)
# !python /content/drive/MyDrive/EE_using_ultralitycs/test_scripts/test_and_validation.py \
  --model /content/drive/MyDrive/EE_using_ultralitycs/results/EE_Backbone_Neck/runs/detect/yolov8n-ee/weights/best.pt \
  --test_dir /content/drive/MyDrive/dataset/dataset/test/ \
  --data_yaml /content/drive/MyDrive/dataset/dataset/data.yaml \
  --conf 0.25 \
  --iou 0.25 \
  --project results_EE_BackboneNeck.txt
# Out:
# Ultralytics 8.3.203 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv8n_ee summary (fused): 100 layers, 5,026,702 parameters, 0 gradients, 16.5 GFLOPs
# val: Fast image access ✅ (ping: 0.4±0.1 ms, read: 18.1±13.7 MB/s, size: 32.1 KB)
# val: Scanning /content/drive/MyDrive/dataset/dataset/test/labels.cache... 1152 images, 5 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1152/1152 16.1Mit/s 0.0s
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 404, len(boxes) = 1720. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 144/144 11.1it/s 12.9s
#                    all       1152       1720      0.885      0.823      0.884      0.725
# Speed: 0.3ms preprocess, 6.7ms inference, 0.0ms loss, 1.8ms postprocess per image
# YOLOv8 Evaluation — 2025-09-23T17:52:20
# Model: /content/drive/MyDrive/EE_using_ultralitycs/results/EE_Backbone_Neck/runs/detect/yolov8n-ee/weights/best.pt
# Test dir: /content/drive/MyDrive/dataset/dataset/test  (#images: 1152)
# Image size: 640 | Device: auto | Batch: 8
#
# == Accuracy (Ultralytics val on test split) ==
# mAP50-95: 0.7252
# mAP50:    0.8840
# Precision (mean): 0.8848
# Recall (mean):    0.8233
#
# == == == == Inference Speed Metrics == == == ==
# Average inference time per image: 16.13 ms
# Throughput (FPS): 62.00
# Total wall time on 1152 images: 18.58 s
#
# Saved results to: results_EE_BackboneNeck.txt/eval_run/results.txt
# (Project outputs are save to: /content/results_EE_BackboneNeck.txt/eval_run)

# %% [markdown]
# ##Pruned model(witour quantizaiton)

# %%
#Prunned model(without Quantization)
# !python /content/drive/MyDrive/EE_using_ultralitycs/test_scripts/test_and_validation.py \
  --model /content/drive/MyDrive/EE_using_ultralitycs/results/EE_Backbone_Neck/pruned/manual_pruned_EE_BackboneNeck.pt \
  --test_dir /content/drive/MyDrive/dataset/dataset/test/ \
  --data_yaml /content/drive/MyDrive/dataset/dataset/data.yaml \
  --conf 0.25 \
  --iou 0.25 \
  --project results_EE_BackboneNeck_pruned.txt

# %% [markdown]
# ##Quantized model(witout Prunning)

# %%
#Quantized model(without Pruning) float 16
# !python /content/drive/MyDrive/EE_using_ultralitycs/test_scripts/test_and_validation.py \
  --model /content/drive/MyDrive/EE_using_ultralitycs/results/EE_Backbone_Neck/quantized/ ... \
  --test_dir /content/drive/MyDrive/dataset/dataset/test/ \
  --data_yaml /content/drive/MyDrive/dataset/dataset/data.yaml \
  --conf 0.25 \
  --iou 0.25 \
  --project results_EE_BackboneNeck_float16.txt

# %%
#Quantized model(without Pruning) Int 8
# !python /content/drive/MyDrive/EE_using_ultralitycs/test_scripts/test_and_validation.py \
  --model /content/drive/MyDrive/EE_using_ultralitycs/results/EE_Backbone_Neck/quantized/ ... \
  --test_dir /content/drive/MyDrive/dataset/dataset/test/ \
  --data_yaml /content/drive/MyDrive/dataset/dataset/data.yaml \
  --conf 0.25 \
  --iou 0.25 \
  --project results_EE_BackboneNeck_int8.txt

# %% [markdown]
# ##Quantized and Pruned model

# %%
#Quantized and Prunned model - Float 16
# !python /content/drive/MyDrive/EE_using_ultralitycs/test_scripts/test_and_validation.py \
  --model /content/drive/MyDrive/EE_using_ultralitycs/results/EE_Backbone_Neck/quantized/ ... \
  --test_dir /content/drive/MyDrive/dataset/dataset/test/ \
  --data_yaml /content/drive/MyDrive/dataset/dataset/data.yaml \
  --conf 0.25 \
  --iou 0.25 \
  --project results_EE_BackboneNeck_pruned_float16.txt

# %%
#Quantized and Prunned model - Int 8
# !python /content/drive/MyDrive/EE_using_ultralitycs/test_scripts/test_and_validation.py \
  --model /content/drive/MyDrive/EE_using_ultralitycs/results/EE_Backbone_Neck/quantized/ ... \
  --test_dir /content/drive/MyDrive/dataset/dataset/test/ \
  --data_yaml /content/drive/MyDrive/dataset/dataset/data.yaml \
  --conf 0.25 \
  --iou 0.25 \
  --project results_EE_BackboneNeck_pruned_int8.txt

# %% [markdown]
# #Early Eixt Based model - Backboneonly

# %%
#Normal Trained model(without Pruning and Quantization)
# !python /content/drive/MyDrive/EE_using_ultralitycs/test_scripts/test_and_validation.py \
  --model /content/drive/MyDrive/EE_using_ultralitycs/results/EE_Backboneonly/yolov8n-ee/weights/best.pt \
  --test_dir /content/drive/MyDrive/dataset/dataset/test/ \
  --data_yaml /content/drive/MyDrive/dataset/dataset/data.yaml \
  --conf 0.25 \
  --iou 0.25 \
  --project results_EE_Backboneonly.txt
# Out:
# Ultralytics 8.3.203 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv8n_ee summary (fused): 100 layers, 5,026,702 parameters, 0 gradients, 16.5 GFLOPs
# val: Fast image access ✅ (ping: 0.4±0.2 ms, read: 30.0±25.0 MB/s, size: 63.9 KB)
# val: Scanning /content/drive/MyDrive/dataset/dataset/test/labels.cache... 1152 images, 5 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1152/1152 13.7Mit/s 0.0s
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 404, len(boxes) = 1720. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 144/144 7.5it/s 19.1s
#                    all       1152       1720      0.885      0.823      0.884      0.725
# Speed: 0.3ms preprocess, 6.9ms inference, 0.0ms loss, 2.0ms postprocess per image
# YOLOv8 Evaluation — 2025-09-23T18:03:16
# Model: /content/drive/MyDrive/EE_using_ultralitycs/results/EE_Backboneonly/yolov8n-ee/weights/best.pt
# Test dir: /content/drive/MyDrive/dataset/dataset/test  (#images: 1152)
# Image size: 640 | Device: auto | Batch: 8
#
# == Accuracy (Ultralytics val on test split) ==
# mAP50-95: 0.7252
# mAP50:    0.8840
# Precision (mean): 0.8848
# Recall (mean):    0.8233
#
# == == == == Inference Speed Metrics == == == ==
# Average inference time per image: 17.08 ms
# Throughput (FPS): 58.56
# Total wall time on 1152 images: 19.67 s
#
# Saved results to: results_EE_Backboneonly.txt/eval_run/results.txt
# (Project outputs are save to: /content/results_EE_Backboneonly.txt/eval_run)

# %% [markdown]
# ##Pruned model(witour quantizaiton)

# %%
#Prunned model(without Quantization)
# !python /content/drive/MyDrive/EE_using_ultralitycs/test_scripts/test_and_validation.py \
  --model /content/drive/MyDrive/EE_using_ultralitycs/results/EE_Backboneonly/pruned/manual_pruned_EE_BackboneOnly.pt \
  --test_dir /content/drive/MyDrive/dataset/dataset/test/ \
  --data_yaml /content/drive/MyDrive/dataset/dataset/data.yaml \
  --conf 0.25 \
  --iou 0.25 \
  --project results_EE_Backboneonly_pruned.txt

# %% [markdown]
# ##Quantized model(witout Prunning)

# %%
#Quantized model(without Pruning) float 16
# !python /content/drive/MyDrive/EE_using_ultralitycs/test_scripts/test_and_validation.py \
  --model /content/drive/MyDrive/EE_using_ultralitycs/results/EE_Backboneonly/quantized/ ... \
  --test_dir /content/drive/MyDrive/dataset/dataset/test/ \
  --data_yaml /content/drive/MyDrive/dataset/dataset/data.yaml \
  --conf 0.25 \
  --iou 0.25 \
  --project results_EE_Backboneonly_float16.txt

# %%
#Quantized model(without Pruning) Int 8
# !python /content/drive/MyDrive/EE_using_ultralitycs/test_scripts/test_and_validation.py \
  --model /content/drive/MyDrive/EE_using_ultralitycs/results/EE_Backbone_Neck/quantized/ ... \
  --test_dir /content/drive/MyDrive/dataset/dataset/test/ \
  --data_yaml /content/drive/MyDrive/dataset/dataset/data.yaml \
  --conf 0.25 \
  --iou 0.25 \
  --project results_EE_BackboneNeck_int8.txt

# %% [markdown]
# ##Quantized and Pruned model

# %%
#Quantized and Prunned model - Float 16
# !python /content/drive/MyDrive/EE_using_ultralitycs/test_scripts/test_and_validation.py \
  --model /content/drive/MyDrive/EE_using_ultralitycs/results/EE_Backboneonly/quantized/ ... \
  --test_dir /content/drive/MyDrive/dataset/dataset/test/ \
  --data_yaml /content/drive/MyDrive/dataset/dataset/data.yaml \
  --conf 0.25 \
  --iou 0.25 \
  --project results_EE_Backboneonly_pruned_float16.txt

# %%
#Quantized and Prunned model - Int 8
# !python /content/drive/MyDrive/EE_using_ultralitycs/test_scripts/test_and_validation.py \
  --model /content/drive/MyDrive/EE_using_ultralitycs/results/EE_Backboneonly/quantized/ ... \
  --test_dir /content/drive/MyDrive/dataset/dataset/test/ \
  --data_yaml /content/drive/MyDrive/dataset/dataset/data.yaml \
  --conf 0.25 \
  --iou 0.25 \
  --project results_EE_Backboneonly_pruned_int8.txt

# %% [markdown]
# #Trained Model Without Early Exit layers

# %%
#Normal Trained model(without Pruning and Quantization)
# !python /content/drive/MyDrive/EE_using_ultralitycs/test_scripts/test_and_validation.py \
  --model /content/drive/MyDrive/EE_using_ultralitycs/results/Model_without_EE/train-results/weights/best.pt \
  --test_dir /content/drive/MyDrive/dataset/dataset/test/ \
  --data_yaml /content/drive/MyDrive/dataset/dataset/data.yaml \
  --conf 0.25 \
  --iou 0.25 \
  --project results_simple_customised_yolov8.txt
# Out:
# Ultralytics 8.3.203 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv8n summary (fused): 72 layers, 3,009,158 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 0.5±0.3 ms, read: 39.5±24.1 MB/s, size: 82.8 KB)
# val: Scanning /content/drive/MyDrive/dataset/dataset/test/labels.cache... 1152 images, 5 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1152/1152 14.7Mit/s 0.0s
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 404, len(boxes) = 1720. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 144/144 12.4it/s 11.6s
#                    all       1152       1720      0.855      0.843      0.882      0.727
# Speed: 0.3ms preprocess, 3.9ms inference, 0.0ms loss, 2.1ms postprocess per image
# YOLOv8 Evaluation — 2025-09-23T17:45:06
# Model: /content/drive/MyDrive/EE_using_ultralitycs/results/Model_without_EE/train-results/weights/best.pt
# Test dir: /content/drive/MyDrive/dataset/dataset/test  (#images: 1152)
# Image size: 640 | Device: auto | Batch: 8
#
# == Accuracy (Ultralytics val on test split) ==
# mAP50-95: 0.7269
# mAP50:    0.8816
# Precision (mean): 0.8554
# Recall (mean):    0.8431
#
# == == == == Inference Speed Metrics == == == ==
# Average inference time per image: 20.75 ms
# Throughput (FPS): 48.20
# Total wall time on 1152 images: 23.90 s
#
# Saved results to: results_simple_customised_yolov8.txt/eval_run/results.txt
# (Project outputs are save to: /content/results_simple_customised_yolov8.txt/eval_run)

# %% [markdown]
# ##Pruned model(witour quantizaiton)

# %%
#Pruned model(withoutearly exit and Quantization)
# !python /content/drive/MyDrive/EE_using_ultralitycs/test_scripts/test_and_validation.py \
  --model /content/drive/MyDrive/EE_using_ultralitycs/results/Model_without_EE/pruned/manual_pruned.pt \
  --test_dir /content/drive/MyDrive/dataset/dataset/test/ \
  --data_yaml /content/drive/MyDrive/dataset/dataset/data.yaml \
  --conf 0.25 \
  --iou 0.25 \
  --project results_EE_manual_pruned_EE_BackboneNeck.txt
# Out:
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/EE_using_ultralitycs/test_scripts/test_and_validation.py", line 99, in <module>
#     main()
#   File "/content/drive/MyDrive/EE_using_ultralitycs/test_scripts/test_and_validation.py", line 53, in main
#     model = YOLO(str(model_path))
#             ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/models/yolo/model.py", line 83, in __init__
#     super().__init__(model=model, task=task, verbose=verbose)
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/engine/model.py", line 153, in __init__
#     self._load(model, task=task)
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/engine/model.py", line 297, in _load
#     self.model, self.ckpt = load_checkpoint(weights)
#                             ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/nn/tasks.py", line 1503, in load_checkpoint
#     model = (ckpt.get("ema") or ckpt["model"]).float()  # FP32 model
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'collections.OrderedDict' object has no attribute 'float'

# %% [markdown]
# ##Quantized Model(without Pruning)

# %%
#Quantized model(without Pruning) - Float16
# !python /content/drive/MyDrive/EE_using_ultralitycs/test_scripts/test_and_validation.py \
  --model /content/drive/MyDrive/EE_using_ultralitycs/results/Model_without_EE/quantized/ ... \
  --test_dir /content/drive/MyDrive/dataset/dataset/test/ \
  --data_yaml /content/drive/MyDrive/dataset/dataset/data.yaml \
  --conf 0.25 \
  --iou 0.25 \
  --project results_simple_customised_yolov8_float16.txt

# %%
#Quantized model(without Pruning) - Int8
# !python /content/drive/MyDrive/EE_using_ultralitycs/test_scripts/test_and_validation.py \
  --model /content/drive/MyDrive/EE_using_ultralitycs/results/Model_without_EE/quantized/ ... \
  --test_dir /content/drive/MyDrive/dataset/dataset/test/ \
  --data_yaml /content/drive/MyDrive/dataset/dataset/data.yaml \
  --conf 0.25 \
  --iou 0.25 \
  --project results_simple_customised_yolov8_int8.txt

# %% [markdown]
# ##Quantized and Pruned Model

# %%
#Quantized and Pruned model - Float16
# !python /content/drive/MyDrive/EE_using_ultralitycs/test_scripts/test_and_validation.py \
  --model /content/drive/MyDrive/EE_using_ultralitycs/results/Model_without_EE/quantized/ ... \
  --test_dir /content/drive/MyDrive/dataset/dataset/test/ \
  --data_yaml /content/drive/MyDrive/dataset/dataset/data.yaml \
  --conf 0.25 \
  --iou 0.25 \
  --project results_simple_customised_yolov8_pruned_float16.txt

# %%
#Quantized and Pruned model - Int8
# !python /content/drive/MyDrive/EE_using_ultralitycs/test_scripts/test_and_validation.py \
  --model /content/drive/MyDrive/EE_using_ultralitycs/results/Model_without_EE/quantized/ ... \
  --test_dir /content/drive/MyDrive/dataset/dataset/test/ \
  --data_yaml /content/drive/MyDrive/dataset/dataset/data.yaml \
  --conf 0.25 \
  --iou 0.25 \
  --project results_simple_customised_yolov8_pruned_int8.txt
